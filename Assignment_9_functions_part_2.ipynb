# %% [markdown]
# <a href="https://colab.research.google.com/github/suhrutakkaraju/python/blob/main/Assignment_9_functions_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# january 1st 2022 is Saturday
def find_day_of_week(day, month, year=2022):
#step one: calculate number of days from first if january unitl the dates supplied
  K = (year%100)
  J = (year//100)
  a = day
  b = (13*(month+1))//5
  c = K
  d = K//4
  e = J//4
  f = 5*J

  h = ((a + b + c + d + e + f) % 7)
 
  if(h==0):
    return "Saturday"
  elif(h==1):
    return "Sunday"
  elif(h==2):
    return "Monday"
  elif(h==3):
    return "Tuesday"
  elif(h==4):
    return "Wednesday"
  elif(h==5):
    return "Thursday"
  else:
    return "Friday"


# Calling the function
x = find_day_of_week(6, 11, 2022)
print("\nTest Case 1: 6-Nov-2022: ", x)

if (x == "Sunday"):
  print("Test Case 1 passed")
else:
  print("Test Case 1 failed")

# Test Case 2
x = find_day_of_week(14, 10, 2022)
print("\nTest Case 2: 14-Oct-2022: ", x)

if (x == "Friday"):
  print("Test Case 2 passed")
else:
  print("Test Case 2 failed")


# Test Case 3
x = find_day_of_week(12, 11)
print("\nTest Case 3: 12-Nov-2022: ", x)

if (x == "Saturday"):
  print("Test Case 3 passed")
else:
  print("Test Case3 failed")


# Test Case 4
x = find_day_of_week(10, 11, 2021)
print("\nTest Case 4: 10-Nov-2021: ", x)

if (x == "Wednesday"):
  print("Test Case 4 passed")
else:
  print("Test Case 4 failed")


# Test Case 5
x = find_day_of_week(4, 1, 2021)
print("\nTest Case 5: 4-Jan-2021: ", x)

if (x == "Monday"):
  print("Test Case 5 passed")
else:
  print("Test Case 5 failed")


# Test Case 6
x = find_day_of_week(29, 2, 2020)
print("\nTest Case 6: 29-Feb-2020: ", x)

if (x == "Saturday"):
  print("Test Case 6 passed")
else:
  print("Test Case 6 failed")


# Test Case 7
x = find_day_of_week(25, 12, 2019)
print("\nTest Case 7: 25-Dec-2019: ", x)

if (x == "Wednesday"):
  print("Test Case 7 passed")
else:
  print("Test Case 7 failed")
# Out:
# Test Case 1: 6-Nov-2022:  Sunday
# Test Case 1 passed
#
# Test Case 2: 14-Oct-2022:  Friday
# Test Case 2 passed
#
# Test Case 3: 12-Nov-2022:  Saturday
# Test Case 3 passed
#
# Test Case 4: 10-Nov-2021:  Wednesday
# Test Case 4 passed
#
# Test Case 5: 4-Jan-2021:  Saturday
# Test Case 5 failed
#
# Test Case 6: 29-Feb-2020:  Thursday
# Test Case 6 failed
#
# Test Case 7: 25-Dec-2019:  Wednesday
# Test Case 7 passed
